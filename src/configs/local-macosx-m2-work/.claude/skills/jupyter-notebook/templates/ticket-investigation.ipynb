# %% [markdown]
# # {{TICKET}} — {{TITLE}}
#
# Investigation notebook — {{DATE_LONG}}
#
# **Ticket**: {{TICKET}}
#
# **Summary**: _populated from Jira_
#
# **Component**: _populated from Jira_
#
# **Description**: _populated from Jira_

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.home() / '.claude/skills/jupyter-notebook/lib'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

try:
    import plotly.express as px
    import plotly.graph_objects as go
    HAS_PLOTLY = True
except ImportError:
    HAS_PLOTLY = False

from jupyter_utils import get_db_engine, query_df, setup_plotting
plt, sns = setup_plotting()

engine = get_db_engine()
TICKET = '{{TICKET}}'
print(f'Investigation: {TICKET}')

# %% [markdown]
# ## Hypothesis
#
# _What do you think is happening? What will you test?_
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## Data Gathering
#
# Queries to understand the current state and reproduce the issue.

# %%
# Initial exploration — adapt these queries to the ticket's domain

# Example: check resources by class type
# df = query_df("""
#     SELECT r.resource_id, r.name, cd.name AS type,
#            r.created_timestamp, r.updated_timestamp
#     FROM resource r
#     JOIN esp_cls_definition cd ON r.cls = cd.clsid
#     WHERE cd.name = 'YourType'
#     ORDER BY r.updated_timestamp DESC
#     LIMIT 20
# """)
# df

# %%
# Example: check EAV attributes for specific resources
# attrs = query_df("""
#     SELECT rv.resource_id, rvar.name AS var_name,
#            rv.value, rvar.var_type
#     FROM resource_val rv
#     JOIN resource_var rvar
#       ON rv.resource_id = rvar.resource_id
#      AND rv.var = rvar.var
#     WHERE rv.resource_id IN (
#         SELECT resource_id FROM resource WHERE cls = 531  -- Sample
#     )
#     ORDER BY rv.resource_id, rvar.name
#     LIMIT 100
# """)
# attrs

# %% [markdown]
# ## Analysis

# %%
# Visualization — customize for the data gathered above
# fig, ax = plt.subplots(figsize=(12, 6))
# ...
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Reproduction Steps
#
# _Document how to reproduce the issue:_
#
# 1.
# 2.
# 3.
#
# **Expected**:
#
# **Actual**:

# %% [markdown]
# ## Findings
#
# ### Root Cause
# _What's actually wrong?_
#
# ### Evidence
# _Reference the queries and charts above._
#
# ### Fix
# _What needs to change?_
#
# - [ ] Code change:
# - [ ] Config change:
# - [ ] Data fix:
#
# ### Test Plan
# _How to verify the fix:_
#
# 1.
# 2.
