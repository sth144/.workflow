# %% [markdown]
# # {{TICKET}} — {{TITLE}}
#
# Investigation notebook — {{DATE_LONG}}
#
# **Ticket**: {{TICKET}}
#
# **Summary**: _populated from Jira_
#
# **Component**: _populated from Jira_
#
# **Description**: _populated from Jira_

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.home() / '.claude/skills/jupyter-notebook/lib'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

try:
    import plotly.express as px
    import plotly.graph_objects as go
    HAS_PLOTLY = True
except ImportError:
    HAS_PLOTLY = False

from jupyter_utils import get_db_engine, query_df, setup_plotting
plt, sns = setup_plotting()

engine = get_db_engine()
TICKET = '{{TICKET}}'
print(f'Investigation: {TICKET}')

# %% [markdown]
# ## Hypothesis
#
# _What do you think is happening? What will you test?_
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## Data Gathering
#
# Queries to understand the current state and reproduce the issue.

# %%
# Initial exploration — adapt these queries to the ticket's domain

# Example: check entity state
# df = query_df("""
#     SELECT e.id, e.entity_type, e.name, e.created_at, e.updated_at
#     FROM entity e
#     WHERE e.entity_type = 'your_type'
#     ORDER BY e.updated_at DESC
#     LIMIT 20
# """)
# df

# %%
# Example: check EAV attributes for specific entities
# attrs = query_df("""
#     SELECT ea.entity_id, ea.attribute_name, ea.attribute_value,
#            ea.created_at, ea.updated_at
#     FROM entity_attribute ea
#     WHERE ea.entity_id IN (SELECT id FROM entity WHERE entity_type = 'your_type')
#     ORDER BY ea.entity_id, ea.attribute_name
#     LIMIT 100
# """)
# attrs

# %% [markdown]
# ## Analysis

# %%
# Visualization — customize for the data gathered above
# fig, ax = plt.subplots(figsize=(12, 6))
# ...
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Reproduction Steps
#
# _Document how to reproduce the issue:_
#
# 1.
# 2.
# 3.
#
# **Expected**:
#
# **Actual**:

# %% [markdown]
# ## Findings
#
# ### Root Cause
# _What's actually wrong?_
#
# ### Evidence
# _Reference the queries and charts above._
#
# ### Fix
# _What needs to change?_
#
# - [ ] Code change:
# - [ ] Config change:
# - [ ] Data fix:
#
# ### Test Plan
# _How to verify the fix:_
#
# 1.
# 2.
